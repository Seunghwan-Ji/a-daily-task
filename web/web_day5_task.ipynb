# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re

def page_source_for_soup(html): # 페이지 소스를 파싱해서 반환
    time.sleep(1)
    return BeautifulSoup(html,'html.parser')

# %%
# 1. 서울시 구별로 스타벅스 매장을 나누어 분석

driver = webdriver.Chrome() # 크롬 실행
time.sleep(1)
url = "https://www.starbucks.co.kr/store/store_map.do" # 접속할 페이지
driver.get(url) # 링크 접속
time.sleep(3) # 접속 시도 지연 시간

# 지역 검색 버튼 클릭
searchAreaBtn = "#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a"
driver.find_element("css selector", searchAreaBtn).click()
time.sleep(1)

# 서울 버튼 클릭
seoul_btn = "#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a"
driver.find_element("css selector", seoul_btn).click()
time.sleep(1)

# 전체 버튼 클릭
allAreaBtn = "#mCSB_2_container > ul > li:nth-child(1) > a"
driver.find_element("css selector", allAreaBtn).click()
time.sleep(1)

soup = page_source_for_soup(driver.page_source) # 현 페이지 내용 파싱
starbucksCount = soup.select("#mCSB_3_container > ul > li > p") # 서울시에 있는 모든 스타벅스 매장 주소 리스트

guDict = {} # 구: 매장 수 딕셔너리

for addr in starbucksCount:
    gu = re.findall("[가-힣]+구", addr.text.strip())[0] # 정규식을 이용하여 각 주소에서 구 이름만 추출합니다.
    if gu in guDict:
        guDict[gu] += 1 # guDict 딕셔너리에 같은 구 이름이 있으면 밸류를 1 증가 시킵니다.
    else: # 처음 등장한 구일 경우
        guDict[gu] = 1

maxArea = "" # 매장이 가장 많은 구
maxCount = 0 # 최대 매장 수
minArea = "" # 매장이 가장 적은 구
minCount = 0 # 최소 매장 수
allSum = 0 # 서울시 모든 매장 수 총 합

for k, v in guDict.items(): # 딕셔너리를 참조하여 매장이 가장 많은곳, 적은곳, 총 합을 계산합니다.
    if maxArea and minArea:
        if v > maxCount:
            maxArea = k
            maxCount = v
        elif v < minCount:
            minArea = k
            minCount = v
    else:
        maxArea = k
        maxCount = v
        minArea = k
        minCount = v
    allSum += v

print(maxArea, maxCount) # 가장 많은 구
print(minArea, minCount) # 가장 적은 구
print(int(allSum / len(guDict))) # 평균 매장 수
# Out:
# 강남구 91
# 강북구 6
# 24

# %%
# 2. 인스타그램에서 '울릉도맛집'을 검색해서 나온 결과물을 스크래핑하여 텍스트만 추출

def insta_func(word): # 주소 고정 패턴 + word 반환
    return "https://www.instagram.com/explore/tags/" + word

driver = webdriver.Chrome() # 크롬 실행
time.sleep(1)
driver.get("https://www.instagram.com/") # 인스타 로그인 페이지 접속
time.sleep(1)
input_id = driver.find_element("css selector", "#loginForm > div > div:nth-child(1) > div > label > input") # 아이디 입력칸
input_pw = driver.find_element("css selector", "#loginForm > div > div:nth-child(2) > div > label > input") # 비번 입력칸
input_id.send_keys("horong0602@gmail.com") # 아이디 입력
time.sleep(1)
input_pw.send_keys("1qwe2asd3zxc@") # 비번 입력
time.sleep(1)
input_pw.submit() # 엔터
time.sleep(3) # 로그인 시도 지연 시간

word = "울릉도맛집" # 키워드
url = insta_func(word) # 접속될 링크
driver.get(url) # 접속
time.sleep(5) # 접속 시도 지연 시간

post = "div._aagw" # 첫번째 포스트 영역
driver.find_element("css selector", post).click() # 포스트 클릭
time.sleep(1)

for page in range(10):
    soup = page_source_for_soup(driver.page_source) # 현 페이지 내용 파싱

    postText = "div._a9zr" # 포스트 내용 영역
    print("<%d번째 게시물>" % (page + 1))
    print(soup.select(postText)[0].text) # 내용 출력
    
    # 댓글 텍스트 출력
    # 댓글 영역
    comments = "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.x15h9jz8.x47corl.xh8yej3.xir0mxb.x1juhsu6 > div > article > div > div.x1qjc9v5.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xdt5ytf.x1iyjqo2.x5wqa0o.xln7xf2.xk390pu.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x65f84u.x1vq45kp.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x11njtxf > div > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul > div:nth-child(3) > div > div"
    print("\n<댓글>")
    print(soup.select(comments)[0].text) # 댓글 출력
    print("=" * 130)

    # 오른쪽 다음 버튼 클릭
    nextBtn = "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div:nth-child(1) > div > div > div._aaqg._aaqh > button > div > span > svg"
    driver.find_element("css selector", nextBtn).click()
    time.sleep(1)
# Out:
# <1번째 게시물>
# free__jenny내년 여름 울릉도 여행에 참고하시라고 만든 #울릉도맛집 모음Zip.🤤🔖 ‘신비섬횟집’ 물회 물회좀 먹어본 여자의 인생 물회 집..🥹 4박 5일 동안 두번 먹었대요. 먹는 방법이 특이해요. 비빔회로 한번, 물회로 두번 죠져 주는데 너무너무 맛있습니다!!! 🔖 ’현포교동반점‘ 중화 비빔밥, 탕수육 울릉도까지 와서 무슨
# foogeul디엠으로 문의 많이 주셨던, 울릉도 독도여행 꿀팁&맛집 풉니다! (혹시 추가 궁금하신점 있으시면 댓글 달아주세요! 답변 드릴게요)📍교통편 *'가보고 싶은 섬' 사이트에서 배편 예약할 수 있음 *만 34세 이하라면 바다로티켓(1년/7,900원)끊어서 국내선박 주중 50% 주말 30% 할인 받을 수 있음*만 34세 이상이라면 보통 울릉도 출발은 강릉 묵호항이나 포항에서 출발하는데, 포항 출발의 경우 ktx 비용 50% 할인 받아 조금 싸게 이동할 수 있음포항-울릉도(왕복) 137,000원 👉소요시간 3:30(파도가 셀 경우, 시간은 길어질 수 있어요)울릉도-독도(왕복) 51,000원 👉소요시간 3:00독도접안 정보👉날씨가 아무리 좋아도 독도 선착장 파도 높이에 따라 접안여부가 결정됩니다. 접안 못할 시 독도 주변을 돌며 선회유람 해주십니다. 저는 정말 감사하게도 독도 땅 밟고 왔네요!📍음식편디엠으로 추천해준 푸글렛들 감사해요!ㅎㅎ<저동>-천금수산(독도새우)-정애분식(홍따밥/홍합따개비밥/꽁치물회) 오징어내장탕도 같이주는데 시원하고 맛있어요!-저동숯불막창 -저동항 제일약국 옆 오징어 회떠주는 집이 있는데 거기서 회떠서 바다보며 먹으면 좋아요! 1마리에 1만원! - 카페는 저동커피나 글림 추천!<도동>-다애식당(따개비밥)-보성식육식당(칡소,약소)-다와호떡(호박식혜와 호떡)-이사부초밥<사동>-심비섬물회<천부>-나리분지야영장식당 -신애분식(따개비칼국수)-만광식당-일호식당-카페울라(저는 못가봤지만, 뷰가 진짜 최고라고 하더라구요)그리고 혹시 차를 가지고 가신다면, 태하쪽 늘푸르니에서 건어물 사시면 좋아요! 📍숙소편-저는 뚜벅이라 저동항에서 거의 숙소를 잡았는데요! 사실 너무 비싸요ㅜ 차가 있으시거나 택시로 이동할 분이라면 천부쪽에 숙소를 잡으시는걸 추천드립니다! 시내를 벗어난 지역이다보니 숙소비도 시내대비 저렴하고 뷰도 더 예쁘답니다! 📍볼거리 -관음도-삼선암-저동도동해안산책로(여긴 태풍의 영향으로 현재 일부구간만 통행할 수 있다고 해요)-촛대바위(저는 이곳에서 일출을 봤어요!)-나리분지 -성인봉(원시림)-봉래폭포-독도일출전망대 케이블카📍그 외 팁! -울릉도는 버스 배차간격이 거의 1시간마다 있어서 항상 버스시간표를 보면서 이동해야 해요! 저처럼 혼자 여행하시거나, 차없이 이동하는 경우 네이버에 울릉도 버스시간표 치시면 나오니 참고하시면 됩니다!-택시는 비싸다고 해서 거의 걸어다녔는데, 거의 10분거리 이동시 14,000원정도 든다고 하네요!#푸글_울릉도 #울릉도맛집 #울릉도여행 #독도여행 #독도 #울릉도수정됨 · 135주
#
# <댓글>
# ==================================================================================================================================
# <7번째 게시물>
# chagyeong_ulleung고객님들 후기사진 잘 올리지 않는 편인데 너무나 감사한 일들이 많았던 고객님☘️오시는 길에 딸기까지 가져다 주시고 또 한번 감동입니다🫶#룸4 #울릉차경 #노을맛집 #온수풀8시간
#
# <댓글>
# superheros_daddy👏8시간좋아요 1개답글 달기댓글 옵션좋아요답글 보기(1개)312.6pm행복한 여행이였습니다 ❤ 감사합니다 🙇🏻‍♀️8시간좋아요 1개답글 달기댓글 옵션좋아요답글 보기(1개)chagyeong_ulleung#울릉도 #바로 #여기8시간답글 달기댓글 옵션좋아요답글 보기(1개)
# ==================================================================================================================================
# <8번째 게시물>
# jinarang_sta울릉도 3박 4일❓여기만 가도 버킷리스트 클리어🧹1️⃣ #행남해안산책로 2️⃣ #독도 3️⃣ #와록사해안산책로 4️⃣ #관음사 5️⃣ #봉래폭포 6️⃣ #나리분지미끄럼틀 7️⃣ #거북바위8️⃣ #카페울라9️⃣ #남서일몰전망대 🔟 #대풍감전망대 🍯Tip. Point만 정리🚢 “가고싶은섬” 에서 자신에게 맞는 배 예약출발지 : 포항, 후포, 묵호, 강릉 도착지 : 도동, 사동, 저동🚘 차를 싣고 갈 수 있는 대형 크루즈는 포항, 후포 2곳에만 존재! 저는 렌트 대신 자차 싣고 여행했어요.🏝️독도가는 배는 “울릉군청-독도접안지수”를 참고하여, 🙆🏻‍♀️접안 가능한 날로 가는 것을 추천!🇰🇷 독도 방문 후, 사동항에있는 독도관리사무소 에서 독도명예주민증(무료) 을 발급받으면 , 각종 관광지 입장료 무료 ✔️ 모노레일은 50% 할인 가능하니 꼭 받으세요. 🏡 숙박은 “내돈내산” 한 숙소지만 강추하는 휘월을 이용했어요 @hwiwol_ 의 작은 room을 이용했구, 아늑한 감성의 숙소라 대만족💛👟 울릉도 대부분의 지형이 언덕이 많고, 트래킹 코스가 많으니 신발과 옷은 편안하게! 😉45주
#
# <댓글>
# djyeomm@lsuonr39주답글 달기댓글 옵션좋아요답글 보기(1개)jinny__vouov@94_sangj 울릉도도ㅠ다녀오장39주좋아요 1개답글 달기댓글 옵션좋아요답글 보기(1개)zziiiinnii@ssuubb073139주좋아요 1개답글 달기댓글 옵션좋아요s.h.noh@h.y_b 울릉도가쟈44주답글 달기댓글 옵션좋아요답글 보기(1개)stay_sanok을릉도 가보고 싶었는데 사진만 봐도 넘 멋찌네요~~44주답글 달기댓글 옵션좋아요foto_nly꺄울 울릉도 글 많이많이 올려주세여🔥🔥44주답글 달기댓글 옵션좋아요jeong_0514_오어앙 ㅠㅠㅠ❤️❤️❤️ 버킷리스트 클리어엉 너무 부러웡요❤️❤️44주답글 달기댓글 옵션좋아요alryob와ㅡ❤️ ❤️울릉도 곳곳을 알려주셔서 넘 감사해여❤️❤️❤️44주답글 달기댓글 옵션좋아요__e.zzi우아ㅠㅠ영상미 미쳐떠여ㅠㅠ❤️❤️ 대박 ..😍 보고 또 보게되는 힐링 영상이다❤️44주답글 달기댓글 옵션좋아요yesnic
# sul_anju_king매늘소스로 샤워를 시키셨네옹😍13주답글 달기댓글 옵션좋아요suk2ng@rlagus_whd31주답글 달기댓글 옵션좋아요mung.moongeee@yupzip.mung.moongeee42주답글 달기댓글 옵션좋아요k_mi_hui@minyegim44주답글 달기댓글 옵션좋아요lfo.zl@ssuv_45주답글 달기댓글 옵션좋아요ssun0___2@kyeong__rim @y_dbbbbbbbb45주답글 달기댓글 옵션좋아요kim__gwajang인증됨비쥬얼 너무 좋은데요!!🥑🥑48주답글 달기댓글 옵션좋아요jihyelizlee진짜 아는맛이 무섭네요 ㅋㅋㅋㅋ너무너무 맛있게 먹었어요 ㅋㅋㅋ48주답글 달기댓글 옵션좋아요segu.3939@ong_ssoon 자기야 여기가여!49주답글 달기댓글 옵션좋아요답글 보기(1개)yommyyam마늘이 많아서 맛나겠어요 👏49주답글 달기댓글 옵션좋아요yujeoxg@t__hho  아 촉촉해뷰이는거바49주답글 달기댓글 옵션좋아요mj_yummy이것땜에 울롱도 가야하나 싶어요?! ^^ 선팔하고 자주 놀러올게요~😍49주답글 달기댓글 옵션좋아요deliciou_ddu이건뭐맥주뿌셔❤️❤️49주답글 달기댓글 옵션좋아요hoonjarro통닭이 살도 실하고 맛나겠어요😍49주답글 달기댓글 옵션좋아요댓글 더 읽어들이기
# ==================================================================================================================================
# <10번째 게시물>
# growthbiz_6037#경주여행코스 #제주개인스냅 #동성로네일 #분당메이크업 #합판가구 #울릉도맛집 #대구속눈썹잘하는곳 #김포필라테스 #답례품캔들 #레터링케이크창업반 #다사눈썹문신 #백일답례떡 #곤지암꽃집 #육아동지 #남자타투추천6일
#
# <댓글>
# ming_jwn.e959😊 와우,정말 좋아요!6일답글 달기댓글 옵션좋아요amktoious_gjitg21자주 놀러올게요 ~! 😍🙌6일답글 달기댓글 옵션좋아요ruj_auys대박 소통하고 지내고 싶어요! 🙌💚6일답글 달기댓글 옵션좋아요_ssxcnr_i와,여기 기억해놔야 할 것 같아요!6일답글 달기댓글 옵션좋아요ukztxqbt사진 하나하나가 섬세하게 표현돼 있어서 좋아요. 📷6일답글 달기댓글 옵션좋아요maseaa_alr갬성 엄지:) 👍👍6일답글 달기댓글 옵션좋아요uutnm.d0모든 순간을 소중히 여기며 보내는 멋진 하루 되세요! 💖🌟6일답글 달기댓글 옵션좋아요vo0z24d이런 필터 어디서 찾으셨나요? 😮6일답글 달기댓글 옵션좋아요taqhephsn2와,찾던 걸 발견해서 정말 감사합니다!6일답글 달기댓글 옵션좋아요숨겨진 댓글 보기숨겨진 댓글 보기이 댓글은 오해의 소지가 있거나, 불쾌하거나, 스팸일 수 있어 숨겨졌습니다. 숨겨진 댓글이라도 누르면 내용이 표시됩니다.
# ==================================================================================================================================

# %%
driver = webdriver.Chrome() # 크롬 실행
time.sleep(1)
url = "https://game.naver.com/esports/League_of_Legends/schedule/lck?date=2024-03" # 접속할 페이지

driver.get(url) # 링크 접속
time.sleep(3) # 접속 시도 지연 시간

soup = page_source_for_soup(driver.page_source) # 현 페이지 내용 파싱
for i in range(2, 30):
    try:
        playResult = "#civ > div > div > div > div.schedule_container__2rbMY > div:nth-child(2) > div.list_wrap__3zIxG > div:nth-child(%d)" % (i)
        playResult = soup.select(playResult)[0].text.strip()
    except:
        break
    else:
        date = re.findall("[0-9월일 ]+[(][가-힣]{1}[)]", playResult)
        time = re.findall("[0-9]{2}:[0-9]{2}", playResult)
        print(date)
        print(time)
        print("\n")
